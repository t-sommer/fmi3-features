# %%
from fmpy import *

# %%
#unzipdir = extract('Dahlquist.fmu')

# model_descriptions = read_model_description(unzipdir)

# instantiate_fmu

filename = 'Reference-FMUs-0.0.16/2.0/VanDerPol.fmu'

result = simulate_fmu(filename)

plot_result(result)
# Out:
# <div>                            <div id="0fe6e81d-32de-492a-a94a-3884a7e65ea7" class="plotly-graph-div" style="height:410px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0fe6e81d-32de-492a-a94a-3884a7e65ea7")) {                    Plotly.newPlot(                        "0fe6e81d-32de-492a-a94a-3884a7e65ea7",                        [{"line":{"color":"#636efa","width":1},"marker":{"color":"#636efa","size":5},"name":"x0","x":[0.0,0.02,0.04,0.06,0.08,0.1,0.12,0.14,0.16,0.18,0.2,0.22,0.24,0.26,0.28,0.3,0.32,0.34,0.36,0.38,0.4,0.42,0.44,0.46,0.48,0.5,0.52,0.54,0.56,0.58,0.6,0.62,0.64,0.66,0.68,0.7000000000000001,0.72,0.74,0.76,0.78,0.8,0.8200000000000001,0.84,0.86,0.88,0.9,0.92,0.9400000000000001,0.96,0.98,1.0,1.02,1.04,1.06,1.08,1.1,1.12,1.1400000000000001,1.16,1.18,1.2,1.22,1.24,1.26,1.28,1.3,1
# ...
